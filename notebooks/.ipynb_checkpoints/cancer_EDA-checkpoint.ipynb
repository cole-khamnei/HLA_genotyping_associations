# %%
# %load_ext autoreload
# %autoreload 2

import os
import sys
sys.path.append(os.path.abspath("../"))

import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from tqdm.notebook import tqdm

import constants, index_tools, data_tools, medical_code_tools
from utilities import *
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %% [markdown]
# # Load BioBank Components

# %%
biobank_data, biobank_index, med_code_mapping = data_tools.load_all_biobank_components()
# Out:
# Importing BioBank Index and Data:
# Missing 0 biobank index names
# UK BioBank Data Loaded.
# Size: 9999 rows x 2781 columns
# Elapsed time: 4.7483 seconds
# Mapping ICD10 Codes: 100%|██████████| 2018/2018 [00:08<00:00, 237.42 feature/s]

# %% [markdown]
# # Constants

# %%
female_specific_cancers = ["breast cancer", "female genital tract cancer", "cervical cancer",
                           "cin/pre-cancer cells cervix", "fallopian tube cancer", "ovarian cancer",
                           "uterine/endometrial cancer", "vaginal cancer", "vulval cancer" ]

male_specific_cancers = ["male genital tract cancer", "penis cancer", "prostate cancer", "testicular cancer"]
sex_specific_cancers = female_specific_cancers + male_specific_cancers

# %% [markdown]
#  # Basic Summary stats

# %%
cancer_data = biobank_data.loc[~biobank_data["cancer_code"].isna()]

# %%
cancer_codes, counts = np.unique(cancer_data["cancer_code"], return_counts=True)

common_cancer_codes = cancer_codes[np.argsort(counts,)[-5:]]
common_cancer_data = cancer_data.loc[cancer_data["cancer_code"].isin(common_cancer_codes)]

fig, ax = plt.subplots(figsize=(14, 6), facecolor="#fffffe")
sns.kdeplot(data=common_cancer_data, x="cancer_dx_age_interpolated", hue="cancer_code", ax=ax,
            cumulative=False, shade=True, common_norm=False, bw_method=.35, alpha=.6)
ax.set_title("Example Plot: Age of Cancer Diagnosis")
add_plt_labels(ax, "cancer_dx_age_interpolated", "Density")
fig.savefig(constants.COVER_PLOTS_GENERIC_FILE_PATH.format("cancer_dx_age.png"), facecolor="#fffffe")

# %%
variables_of_interest = ["sex", "cancer_code"]

grouping_df = cancer_data[variables_of_interest].copy(deep=True)
grouping_df["total"] = grouping_df["sex"] != "nothing"
grouping_df["female"] = grouping_df["sex"] == "Female"
grouping_df["male"] = grouping_df["sex"] == "Male"
grouping_df = grouping_df.groupby("cancer_code").sum().reset_index()

# grouping_df = grouping_df.loc[ ~grouping_df["cancer_code"].isin(sex_specific_cancers)]
grouping_df = grouping_df.query("total > 5").sort_values("total", ascending=False)

grouping_df["male_fraction"] = grouping_df["male"] / grouping_df["total"]
grouping_df["female_fraction"] = grouping_df["female"] / grouping_df["total"]
grouping_df
# Out:
#                              cancer_code  total  female  male  male_fraction  \
# 4                          breast cancer    217     216     1       0.004608
# 1                   basal cell carcinoma     91      47    44       0.483516
# 22                    malignant melanoma     75      41    34       0.453333
# 34                       prostate cancer     62       0    62       1.000000
# 6                        cervical cancer     37      37     0       0.000000
# 2                         bladder cancer     31      10    21       0.677419
# 9            cin/pre-cancer cells cervix     30      30     0       0.000000
# 10           colon cancer/sigmoid cancer     30      14    16       0.533333
# 39                           skin cancer     27      15    12       0.444444
# 25                 non-hodgkins lymphoma     24       9    15       0.625000
# 48            uterine/endometrial cancer     21      21     0       0.000000
# 16  large bowel cancer/colorectal cancer     17       4    13       0.764706
# 26              non-melanoma skin cancer     16       8     8       0.500000
# 44                     testicular cancer     16       0    16       1.000000
# 29                        ovarian cancer     13      13     0       0.000000
# 36                          rodent ulcer     11       9     2       0.181818
# 15              kidney/renal cell cancer     10       4     6       0.600000
# 35                         rectal cancer      9       2     7       0.777778
# 42               squamous cell carcinoma      9       6     3       0.333333
# 45                        thyroid cancer      9       8     1       0.111111
# 17                  larynx/throat cancer      8       2     6       0.750000
# 14  hodgkins lymphoma / hodgkins disease      8       2     6       0.750000
# 41    small intestine/small bowel cancer      8       1     7       0.875000
# 38                  sarcoma/fibrosarcoma      7       5     2       0.285714
# 47                        unclassifiable      7       4     3       0.428571
# 43                        stomach cancer      6       2     4       0.666667
#
#     female_fraction
# 4          0.995392
# 1          0.516484
# 22         0.546667
# 34         0.000000
# 6          1.000000
# 2          0.322581
# 9          1.000000
# 10         0.466667
# 39         0.555556
# 25         0.375000
# 48         1.000000
# 16         0.235294
# 26         0.500000
# 44         0.000000
# 29         1.000000
# 36         0.818182
# 15         0.400000
# 35         0.222222
# 42         0.666667
# 45         0.888889
# 17         0.250000
# 14         0.250000
# 41         0.125000
# 38         0.714286
# 47         0.571429
# 43         0.333333

# %%
fig, ax = plt.subplots(figsize=(14, 5))
data = grouping_df.sort_values("male_fraction")
ax.bar(data=data, x="cancer_code", height="female_fraction",
       bottom="male_fraction", label="Female", alpha=.6)
ax.bar(data=data, x="cancer_code", height="male_fraction", label="Male", alpha=.6)
plt.draw()
add_plt_labels(ax=ax, x="Cancer Type", y="Fraction")
ax.legend(title="Sex")
ax.set_title("Cancer Sex Distributions by Type")
ax.set_xticklabels([t._text.title() for t in ax.get_xticklabels()], rotation="-60", ha="left");
# Out:
# <ipython-input-240-c2c4216e7257>:10: UserWarning: FixedFormatter should only be used together with FixedLocator
#   ax.set_xticklabels([t._text.title() for t in ax.get_xticklabels()], rotation="-60", ha="left");

# %%
fig, ax = plt.subplots(figsize=(14, 5))
data = grouping_df.sort_values("total", ascending=False)
ax.bar(data=data, x="cancer_code", height="female", bottom="male", label="Female", alpha=.6)
ax.bar(data=data, x="cancer_code", height="male", label="Male", alpha=.6)
plt.draw()
add_plt_labels(ax=ax, x="Cancer Type", y="Counts")
ax.legend(title="Sex")
ax.set_title("Cancer Counts by Type")
ax.set_xticklabels([t._text.title() for t in ax.get_xticklabels()], rotation="-60", ha="left");
# Out:
# <ipython-input-241-9fdf28f58aa7>:9: UserWarning: FixedFormatter should only be used together with FixedLocator
#   ax.set_xticklabels([t._text.title() for t in ax.get_xticklabels()], rotation="-60", ha="left");

# %%
x, y, hue = "cancer_dx_age_interpolated", "density", "sex"
cancer_types = exclude(sorted(cancer_data["cancer_code"].unique()), sex_specific_cancers)

for cancer_code in cancer_types:
    data = cancer_data.query(f"cancer_code == '{cancer_code}'")
    counts = np.unique(data[hue], return_counts=True)[1]
    if len(data) < 20 or len(counts) <= 1:
        continue
        
    fig, ax = plt.subplots(figsize=(12, 6))
    kde_plot(data=data, x=x, hue=hue, ax=ax, bw_method=.3)
    add_plt_labels(ax, x=x, y=y)
    ax.set_title(f"{cancer_code.title()} Diagnosis Age")

# %% [markdown]
# # Viral Associations

# %%
def biobank_search(term: str, biobank_data: pd.DataFrame) -> pd.DataFrame:
    """ Searchs for codes that resemble the search term and the counts the occurences in biobank"""
    df = med_code_mapping.search_codes(term)
    return df

biobank_search

# %%
med_code_mapping.search_codes("mononucleosis")
# Out:
#     coding                                            meaning code_format  \
# 0        0                                                 No           7
# 362   1567  infectious mononucleosis / glandular fever / e...           6
# 0        0                                                 No      100267
# 0        0                                                 No      100264
# 2        9                                                 No      100258
# 2        0                                                 No      100564
# 1        0                                                 No         503
# 2        0                                                 No      100349
# 2        0                                                 No         502
# 2        0                                                 No      100599
# 1        0                                                 No      100370
# 3        0                                                 No      100416
# 1        0                                                 No      100358
# 2        0                                                 No      100563
# 3        0                                                 No      100617
# 2        0                                                 No      100603
# 1        0                                                 No      100400
# 1        0                                                 No      100579
# 1        0                                                 No        1021
# 2        0                                                 No        1022
# 3        2                                                 No      100345
# 668    075                       075 Infectious mononucleosis          87
# 669   0759                      0759 Infectious mononucleosis          87
# 1        0                                                 No         524
# 1        0                                                 No      100352
# 1        0                                                 No      100347
# 580    B27                       B27 Infectious mononucleosis          19
# 581   B270               B27.0 Gammaherpesviral mononucleosis          19
# 582   B271                B27.1 Cytomegaloviral mononucleosis          19
# 583   B278               B27.8 Other infectious mononucleosis          19
# 584   B279        B27.9 Infectious mononucleosis; unspecified          19
# 1        0                                                 No      100668
#
#                                                  name
# 0                                           asthma_dx
# 362                                      illness_code
# 0                                    pregnant_current
# 0                                phasing_use_chr_1_22
# 2                                   birth_weigh_known
# 2                                                None
# 1       GI_IBS_initial_symptoms_co-occuring_infection
# 2                              birth_maternal_smoking
# 2                                           GI_IBS_dx
# 2                                                None
# 1                                 n_household_smokers
# 3                                  alcohol_with_meals
# 1           tobacco_smoking_current_stop_attempt_ever
# 2                                                None
# 3                           diabetes_gestational_only
# 2                                           cancer_dx
# 1                  major_dietary_changes_past_5_years
# 1                                                None
# 1             GI_IBS_initial_symptoms_bloody_diarrhea
# 2                              GU_menstrual_pain_only
# 3                                                None
# 668                                  cancer_type_ICD9
# 669                                  cancer_type_ICD9
# 1                  alcohol_injury_self_or_others_ever
# 1                                 alcohol_former_user
# 1                             tobacco_smoking_current
# 580                                 cancer_type_ICD10
# 581                                 cancer_type_ICD10
# 582                                 cancer_type_ICD10
# 583                                 cancer_type_ICD10
# 584                                 cancer_type_ICD10
# 1    tobacco_smoking_stopped_more_than_6_months_pilot

# %%
MONONUCLEOSIS_LABEL = 'infectious mononucleosis / glandular fever / epstein barr virus (ebv)'
HIV_AIDS_LABELS = "hiv/aids"

# %%
biobank_data.query("cancer_tumor_histology == 'SystemicEBV positive T-cell lymphoproliferative disease of childhood'")
# Out:
# Empty DataFrame
# Columns: [eid, verbal_interview_duration, verbal_interview_duration_1.0, verbal_interview_duration_2.0, sex, birth_year, bp_device, bp_device_1.0, bp_device_2.0, bp_manual_device_ID, bp_manual_device_ID_2.0, birth_month, assessment_date, assessment_date_1.0, assessment_date_2.0, assessment_center, assessment_center_1.0, assessment_center_2.0, cancer_first_year_age, cancer_first_year_age_0.1, cancer_first_year_age_0.2, cancer_first_year_age_1.0, cancer_first_year_age_1.1, cancer_first_year_age_2.0, cancer_first_year_age_2.1, cancer_first_year_age_2.2, illness_first_year_age, illness_first_year_age_0.1, illness_first_year_age_0.2, illness_first_year_age_0.3, illness_first_year_age_0.4, illness_first_year_age_0.5, illness_first_year_age_0.6, illness_first_year_age_0.7, illness_first_year_age_0.8, illness_first_year_age_0.9, illness_first_year_age_0.10, illness_first_year_age_0.11, illness_first_year_age_0.12, illness_first_year_age_0.13, illness_first_year_age_0.14, illness_first_year_age_0.15, illness_first_year_age_0.16, illness_first_year_age_1.0, illness_first_year_age_1.1, illness_first_year_age_1.2, illness_first_year_age_1.3, illness_first_year_age_1.4, illness_first_year_age_1.5, illness_first_year_age_1.6, illness_first_year_age_1.7, illness_first_year_age_1.8, illness_first_year_age_1.9, illness_first_year_age_1.10, illness_first_year_age_2.0, illness_first_year_age_2.1, illness_first_year_age_2.2, illness_first_year_age_2.3, illness_first_year_age_2.4, illness_first_year_age_2.5, illness_first_year_age_2.6, illness_first_year_age_2.7, illness_first_year_age_2.8, illness_first_year_age_2.9, illness_first_year_age_2.10, illness_first_year_age_2.11, illness_first_year_age_2.12, illness_first_year_age_2.13, illness_first_year_age_2.14, illness_first_year_age_2.15, illness_first_year_age_2.16, illness_first_year_age_2.17, illness_first_year_age_2.18, illness_first_year_age_2.19, illness_first_year_age_2.20, illness_first_year_age_2.21, illness_first_year_age_2.22, illness_first_year_age_2.23, illness_first_year_age_2.24, illness_first_year_age_2.25, illness_first_year_age_2.26, illness_first_year_age_2.27, illness_first_year_age_2.28, illness_first_year_age_2.29, illness_first_year_age_2.30, illness_first_year_age_2.31, systolic_bp_manual, systolic_bp_manual_0.1, systolic_bp_manual_1.0, systolic_bp_manual_1.1, systolic_bp_manual_2.0, systolic_bp_manual_2.1, diastolic_bp_manual, diastolic_bp_manual_0.1, diastolic_bp_manual_1.0, diastolic_bp_manual_1.1, diastolic_bp_manual_2.0, diastolic_bp_manual_2.1, pulse_rate_manual, pulse_rate_manual_0.1, ...]
# Index: []
#
# [0 rows x 2018 columns]
