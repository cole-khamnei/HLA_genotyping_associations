# %%
# %load_ext autoreload
# %autoreload 2

import os
import sys
HLA_associations_path = os.path.abspath("../")
sys.path.append(HLA_associations_path)

import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from tqdm.notebook import tqdm

import constants, index_tools, data_tools, medical_code_tools
from utilities import *

# %%
sns.set_palette("tab10")
plt.rcParams.update({'figure.max_open_warning': 0})

# %%
loaded = False

# %% [markdown]
# # Load BioBank Components

# %%
DEV_MODE = False
SIGNIFIER = ""

if not loaded:
    (biobank_data_no_HLA_alleles, biobank_index,
     med_code_mapping) = data_tools.load_all_biobank_components(DEV_MODE, signifier=SIGNIFIER)
    loaded = True
    HLA_alleles = data_tools.load_HLA_data()
    biobank_data = biobank_data_no_HLA_alleles.merge(HLA_alleles, how="left", on="eid")
# Out:
# Importing BioBank Index and Data:
# Missing 0 biobank index names
# Reduced feature set has 369 features.
# UK BioBank Data Loaded.
# Size: 502536 rows x 369 columns
# Elapsed time: 70.3011 seconds
# Mapping Medical Codes: 100%|██████████| 354/354 [04:15<00:00,  1.38 feature/s]

# %% [markdown]
# # Constants

# %%
female_specific_cancers = ["breast cancer", "female genital tract cancer", "cervical cancer",
                           "cin/pre-cancer cells cervix", "fallopian tube cancer", "ovarian cancer",
                           "uterine/endometrial cancer", "vaginal cancer", "vulval cancer" ]

male_specific_cancers = ["male genital tract cancer", "penis cancer", "prostate cancer", "testicular cancer"]
sex_specific_cancers = female_specific_cancers + male_specific_cancers

# %% [markdown]
# # Viral Codes

# %%
mononucleosis_code = 'infectious mononucleosis / glandular fever / epstein barr virus (ebv)'
hiv_code = 'hiv/aids'
herpes_simplex_code = "herpes simplex"
hepatitis_code = "infective/viral hepatitis"

autoimmune_conditions = ["type 1 diabetes", "gestational diabetes", "rheumatoid arthritis",
                         "psoriasis", "asthma", "multiple sclerosis", "systemic lupus erythematosis/sle",
                         "inflammatory bowel disease", "grave's disease", "hypothyroidism/myxoedema",
                         "hyperthyroidism/thyrotoxicosis", "myasthenia gravis", "pernicious anaemia",
                         "sjogren's syndrome/sicca syndrome", "eczema/dermatitis",
                         'acute infective polyneuritis/guillain-barre syndrome', "malabsorption/coeliac disease",
                        ]

psychiatric_conditions = ["schizophrenia", "depression", "mania/bipolar disorder/manic depression",
                          "obsessive compulsive disorder (ocd)", "anxiety/panic attacks",
                          "alcohol dependency"]

HLA_dosing_conditions = {"psychiatric": psychiatric_conditions, "autoimmune": autoimmune_conditions}

other_conditions = ["vasculitis", "hypertension"]
neurological_conditions = ["epilepsy"]

data_tools.biobank_search(med_code_mapping, biobank_data, ('alz'))
# Out:
#           coding                                            meaning  \
# 136         1263           dementia/alzheimers/cognitive impairment
# 2619        3310                           3310 Alzheimer's disease
# 456   1140856246                            salzone 120mg/5ml syrup
# 2709         F00                F00 Dementia in Alzheimer's disease
# 2710        F000  F00.0 Dementia in Alzheimer's disease with ear...
# 2711        F001  F00.1 Dementia in Alzheimer's disease with lat...
# 2712        F002  F00.2 Dementia in Alzheimer's disease; atypica...
# 2713        F009  F00.9 Dementia in Alzheimer's disease; unspeci...
# 3270         G30                            G30 Alzheimer's disease
# 3271        G300         G30.0 Alzheimer's disease with early onset
# 3272        G301          G30.1 Alzheimer's disease with late onset
# 3273        G308                    G30.8 Other Alzheimer's disease
# 3274        G309             G30.9 Alzheimer's disease; unspecified
# 14            10                       Alzheimer's disease/dementia
#
#      code_format                      name  count
# 136            6              illness_code     39
# 2619          87          cancer_type_ICD9      0
# 456            4            treatment_code      0
# 2709          19         cancer_type_ICD10      0
# 2710          19         cancer_type_ICD10      0
# 2711          19         cancer_type_ICD10      0
# 2712          19         cancer_type_ICD10      0
# 2713          19         cancer_type_ICD10      0
# 3270          19         cancer_type_ICD10      0
# 3271          19         cancer_type_ICD10      0
# 3272          19         cancer_type_ICD10      0
# 3273          19         cancer_type_ICD10      0
# 3274          19         cancer_type_ICD10      0
# 14          1010  father_adopted_illnesses      0

# %%
illness = "hypertension"
print(illness.upper())
data["illness_value"] = 1 * (biobank_data["illness_code"] == illness)
print("\t" + zygosity_OR_test(data).replace('\n', '\n\t'))
# Out:
# HYPERTENSION
# 	Zygosity = 1   OR: nan   P-Value: 1.00000   95% CI: nan - nan   N = 0
# 	Zygosity = 2   OR: nan   P-Value: 1.00000   95% CI: nan - nan   N = 5,035
# 	Zygosity = 3   OR: nan   P-Value: 1.00000   95% CI: nan - nan   N = 0
# <ipython-input-514-6be8d5ad92d4>:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data["illness_value"] = 1 * (biobank_data["illness_code"] == illness)
# <ipython-input-512-8d95a531e049>:19: RuntimeWarning: divide by zero encountered in true_divide
#   standard_error = np.sqrt(np.sum(1 / np.array([disease_exposure, disease_no_exposure,

# %%
codes, counts = np.unique(biobank_data["illness_code"].dropna(), return_counts=True)
for code, count in zip(codes[np.argsort(counts)], counts[np.argsort(counts)]):
    print(code, count)
# Out:
# diabetic neuropathy/ulcers 1
# diabetes insipidus 1
# varicella zoster virus 1
# alpha-1 antitrypsin deficiency 1
# synovitis 1
# chlamydia 1
# benign insulinoma 1
# epicondylitis 2
# phaeochromocytoma 2
# dermatopolymyositis 2
# pancytopenia 2
# giardia / giardiasis 2
# aortic dissection 2
# pericardial effusion 2
# aortic aneurysm rupture 3
# fracture sternum 3
# oesophageal varicies 3
# microscopic polyarteritis 3
# myelofibrosis 4
# polyartertis nodosa 4
# ischaemic stroke 4
# iga nephropathy 4
# bowel / intestinal infarction 4
# mitral stenosis 5
# respiratory failure 5
# varicose ulcer 5
# pleural effusion 5
# empyema 5
# dengue fever 5
# sick sinus syndrome 5
# other venous/lymphatic disease 6
# antiphospholipid syndrome 6
# carcinoid syndrome/tumour 7
# bowel / intestinal perforation 7
# bile duct disease 7
# allergy to nickel 7
# opioid dependency 7
# incisional hernia 7
# disorder of adrenal gland 7
# lung abscess 8
# allergy to elastoplast 8
# schistosomiasis/bilharzia 8
# cervical problem 9
# adrenal tumour 9
# other substance abuse/dependency 9
# typhoid fever 10
# male infertility 10
# paraplegia 11
# aortic valve disease 11
# mrsa / methicillin resistant staphylococcus aureus 11
# aortic aneurysm 11
# kidney nephropathy 11
# spinal abscess 12
# aplastic anaemia 12
# deliberate self-harm/suicide attempt 12
# monoclonal gammopathy/not myeloma 12
# retinitis pigmentosa 12
# mitral valve disease 12
# bile duct obstruction/ascending cholangitis 12
# cushings syndrome 13
# dermatomyositis 13
# chronic laryngitis 13
# glomerulnephritis 13
# alcoholic liver disease / alcoholic cirrhosis 13
# essential thrombocytosis 14
# thyroid radioablation therapy 14
# stevens johnson syndrome 14
# fracture thumb 14
# scrotal problem (not cancer) 15
# diphtheria 15
# giant cell/temporal arteritis 15
# renal failure requiring dialysis 16
# arterial embolism 16
# pyelonephritis 16
# soft tissue inflammation 16
# bowen's disease 16
# fracture metatarsal 17
# fracture ulna 17
# sclerosing cholangitis 17
# paget's disease 18
# infection of nervous system 18
# pemphigoid/pemphigus 18
# housemaid's knee (prepatellar bursitis) 18
# anal problem 18
# pancreatic disease 19
# acromegaly 19
# pleural plaques (not known asbestosis) 19
# pulmonary fibrosis 20
# pelvic inflammatory disease/ pid 20
# fracture neck / cervical fracture 20
# atrial flutter 21
# ovarian problem 21
# fibrosing alveolitis/unspecified alveolitis 21
# myeloproliferative disorder 21
# femoral hernia 23
# myocarditis 23
# motor neurone disease 23
# aortic stenosis 23
# mitral regurgitation / incompetence 23
# respiratory infection 23
# cervical erosion 23
# uterine problem 23
# other demyelinating disease (not multiple sclerosis) 24
# oesophageal stricture 24
# rectal prolapse 24
# parathyroid hyperplasia/adenoma 24
# blepharitis / eyelid infection 25
# hyperparathyroidism 25
# polymyositis 25
# hydatiform mole 26
# spina bifida 26
# hypertrophic cardiomyopathy (hcm / hocm) 26
# gastroenteritis/dysentry 26
# haemophilia 26
# brain abscess/intracranial abscess 27
# venous thromboembolic disease 27
# contact dermatitis 27
# haemochromatosis 27
# diabetic eye disease 27
# aortic regurgitation / incompetence 27
# fracture shoulder / scapula 28
# chronic skin ulcers 28
# bursitis 28
# gastrointestinal bleeding 28
# disorder or pituitary gland 28
# renal/kidney failure 28
# obsessive compulsive disorder (ocd) 29
# vocal cord polyp 30
# wolff parkinson white / wpw syndrome 30
# rubella / german measles 31
# sickle cell disease 31
# hyperprolactinaemia 31
# hepatitis b 31
# wegners granulmatosis 32
# fracture face / orbit / eye socket 32
# erectile dysfunction / impotence 33
# spinal stenosis 33
# allergy to house dust mite 33
# primary biliary cirrhosis 34
# vitiligo 34
# mitral valve prolapse 35
# neurological injury/trauma 35
# heart failure/pulmonary odema 35
# benign / essential tremor 35
# fracture pelvis 35
# fracture rib 36
# pericarditis 36
# nephritis 37
# fracture toe 37
# cervical polyps 38
# optic neuritis 38
# parathyroid gland problem (not cancer) 38
# renal failure not requiring dialysis 39
# dementia/alzheimers/cognitive impairment 39
# subdural haemorrhage/haematoma 39
# lichen sclerosis 40
# fracture jaw 40
# fracture hand 40
# polycystic kidney 40
# fracture radius 42
# plantar fascitis 43
# interstitial lung disease 43
# benign neuroma 43
# vasculitis 44
# grave's disease 44
# alopecia / hair loss 44
# retinal artery/vein occlusion 44
# hepatitis c 44
# herpes simplex 44
# neutropenia/lymphopenia 45
# meningioma / benign meningeal tumour 45
# lichen planus 46
# scleroderma/systemic sclerosis 46
# brain haemorrhage 47
# fibrocystic disease 47
# fracture foot 47
# bowel / intestinal obstruction 48
# anal fissure 50
# emphysema 50
# pyloric stenosis 51
# asbestosis 51
# food intolerance 51
# breast fibroadenoma 52
# pneumothorax 52
# cellulitis 52
# constipation 53
# peripheral nerve injury 54
# dysmenorrhoea / dysmenorrhea 54
# leg claudication/ intermittent claudication 54
# iritis 56
# umbilical hernia 56
# trigemminal neuralgia 57
# polycythaemia vera 57
# thalassaemia 58
# fracture patella / knee 59
# myositis/myopathy 59
# gall bladder disease 60
# dupuytren's contracture 60
# fracture neck of femur / hip 61
# post-traumatic stress disorder 62
# labyrinthitis 63
# inflammatory bowel disease 64
# tendonitis / tendinitis / tenosynovitis 64
# undescended testicle 64
# macular degeneration 64
# mumps / epidemic parotitis 65
# abdominal hernia 65
# peripheral nerve disorder 66
# fracture fibula 66
# chronic/degenerative neurological problem 66
# septicaemia / sepsis 66
# fracture finger 68
# prostatitis 69
# whooping cough / pertussis 69
# fracture vertebra / crush fracture / vertebral collapse 70
# acute infective polyneuritis/guillain-barre syndrome 70
# hypopituitarism 72
# fracture skull / head 72
# tennis elbow / lateral epicondylitis 72
# fracture shaft of femur 72
# myasthenia gravis 73
# lymphoedema 73
# connective tissue disorder 74
# hepatitis a 76
# adrenocortical insufficiency/addison's disease 76
# cerebral palsy 77
# svt / supraventricular tachycardia 77
# cystitis 78
# otosclerosis 79
# pericardial problem 79
# oesophageal disorder 80
# breast disease (not cancer) 82
# fracture tibia 83
# cerebral aneurysm 84
# insomnia 85
# dry eyes 86
# cranial nerve problem/palsy 86
# shingles 87
# ureteric obstruction/hydronephrosis 88
# liver failure/cirrhosis 93
# urticaria 96
# acne/acne vulgaris 99
# neck problem/injury 99
# scoliosis 100
# fracture clavicle / collar bone 100
# ectopic pregnancy 101
# burns 102
# menopausal symptoms / menopause 103
# gestational diabetes 103
# encephalitis 104
# disc problem 106
# throat or larynx disorder 109
# thyroiditis 111
# vertigo 111
# post-natal depression 112
# stress 113
# cardiomyopathy 120
# sjogren's syndrome/sicca syndrome 121
# clotting disorder/excessive bleeding 121
# carpal tunnel syndrome 121
# peripheral neuropathy 123
# peptic ulcer 123
# fracture nose 124
# raynaud's phenomenon/disease 124
# eye infection 125
# jaundice (unknown cause) 127
# pituitary adenoma/tumour 128
# cholecystitis 130
# bell's palsy/facial nerve palsy 131
# polio / poliomyelitis 131
# psychological/psychiatric problem 134
# other abdominal problem 136
# anorexia/bulimia/other eating disorder 139
# scarlet fever / scarlatina 141
# female infertility 142
# alcohol dependency 145
# hereditary/genetic haematological disorder 145
# low platelets/platelet disorder 146
# nervous breakdown 146
# dyspepsia / indigestion 147
# subarachnoid haemorrhage 149
# testicular problems (not cancer) 150
# eye trauma 155
# gastritis/gastric erosions 162
# thyroid goitre 162
# spinal cord disorder 167
# infectious mononucleosis / glandular fever / epstein barr virus (ebv) 169
# type 1 diabetes 176
# fracture forearm / wrist 182
# retinal problem 184
# spinal injury 186
# tinnitus / tiniitis 190
# fibromyalgia 191
# other respiratory problems 191
# polycystic ovaries/polycystic ovarian syndrome 198
# fracture upper arm / humerus / elbow 199
# non-infective hepatitis 201
# irregular heart beat 201
# measles / morbillivirus 203
# miscarriage 204
# cervical intra-epithelial neoplasia (cin) / precancerous cells cervix 205
# fracture wrist / colles fracture 211
# liver/biliary/pancreas problem 212
# rosacea 217
# disc degeneration 219
# menorrhagia (unknown cause) 220
# hepatitis 227
# hiv/aids 228
# anaemia 233
# systemic lupus erythematosis/sle 240
# peripheral vascular disease 242
# schizophrenia 251
# blistering/desquamating skin disorder 252
# bph / benign prostatic hypertrophy 253
# gynaecological disorder (not cancer) 260
# helicobacter pylori 260
# malaria 260
# prostate problem (not cancer) 265
# osteomyelitis 268
# sleep apnoea 269
# pancreatitis 290
# psoriatic arthropathy 295
# abnormal smear (cervix) 296
# trapped nerve/compressed nerve 298
# bronchiectasis 303
# stomach disorder 308
# polymyalgia rheumatica 309
# urinary frequency / incontinence 311
# chronic obstructive airways disease/copd 312
# haemorrhoids / piles 314
# rectal or colon adenoma/polyps 331
# osteopenia 332
# uterine polyps 337
# pernicious anaemia 352
# spontaneous pneumothorax/recurrent pneumothorax 363
# pleurisy 363
# chickenpox 368
# head injury 374
# fracture lower leg / ankle 375
# bone disorder 376
# benign breast lump 390
# varicose veins 393
# sarcoidosis 396
# nasal polyps 406
# joint pain 411
# oesophagitis/barretts oesophagus 413
# peritonitis 417
# retinal detachment 422
# heart/cardiac problem 430
# parkinsons disease 432
# allergy or anaphylactic reaction to food 442
# nasal/sinus disorder 450
# inguinal hernia 455
# other renal/kidney problem 458
# thyroid problem (not cancer) 471
# infective/viral hepatitis 474
# transient ischaemic attack (tia) 475
# duodenal ulcer 492
# ankylosing spondylitis 495
# rheumatic fever 497
# meniere's disease 508
# breast cysts 513
# colitis/not crohns or ulcerative colitis 535
# urinary tract infection/kidney infection 547
# mania/bipolar disorder/manic depression 561
# vaginal prolapse/uterine prolapse 605
# joint disorder 636
# other neurological problem 652
# bladder problem (not cancer) 665
# tonsiltis 691
# cervical spondylosis 699
# allergy/hypersensitivity/anaphylaxis 729
# meningitis 732
# allergy or anaphylactic reaction to drug 736
# crohns disease 749
# other joint disorder 758
# muscle or soft tissue injuries 759
# heart arrhythmia 777
# chronic sinusitis 784
# back pain 798
# type 2 diabetes 811
# iron deficiency anaemia 828
# eye/eyelid problem 839
# spine arthritis/spondylitis 855
# tuberculosis (tb) 869
# chronic fatigue syndrome 892
# bronchitis 918
# gastric/stomach ulcers 921
# malabsorption/coeliac disease 974
# heart valve problem/heart murmur 979
# muscle/soft tissue problem 990
# arthritis (nos) 1026
# atrial fibrillation 1050
# multiple sclerosis 1061
# gestational hypertension/pre-eclampsia 1067
# kidney stone/ureter stone/bladder stone 1075
# appendicitis 1120
# ear/vestibular disorder 1137
# essential hypertension 1149
# headaches (not migraine) 1152
# ovarian cyst or cysts 1162
# ulcerative colitis 1209
# sciatica 1214
# diverticular disease/diverticulitis 1322
# endometriosis 1363
# gout 1523
# hyperthyroidism/thyrotoxicosis 1582
# pulmonary embolism +/- dvt 1625
# anxiety/panic attacks 1649
# epilepsy 1811
# psoriasis 1889
# rheumatoid arthritis 1970
# pneumonia 1980
# enlarged prostate 1997
# cholelithiasis/gall stones 2025
# glaucoma 2055
# uterine fibroids 2193
# prolapsed disc/slipped disc 2464
# cataract 2488
# osteoporosis 2590
# hiatus hernia 2605
# back problem 2641
# eczema/dermatitis 3191
# irritable bowel syndrome 3414
# emphysema/chronic bronchitis 3566
# gastro-oesophageal reflux (gord) / gastric reflux 4746
# migraine 4896
# stroke 5206
# deep venous thrombosis (dvt) 5849
# diabetes 5874
# unclassifiable 6248
# depression 8123
# hayfever/allergic rhinitis 8948
# high cholesterol 9271
# hypothyroidism/myxoedema 9373
# angina 10908
# heart attack/myocardial infarction 11208
# osteoarthritis 11342
# asthma 37724
# hypertension 114035

# %% [markdown]
#  # Exploring ICD 10 Cancer Types

# %%
ICD10_data = biobank_data.loc[~biobank_data["cancer_type_ICD10"].isna()].copy(deep=True)

# %%
display(data_tools.biobank_search(med_code_mapping, biobank_data, ("C82")).query("name == 'cancer_type_ICD10'"))
display(data_tools.biobank_search(med_code_mapping, biobank_data,
                                  ("non-hodg")).query("name == 'cancer_type_ICD10' and count != 0"))
# Out:
#      coding                                            meaning code_format  \
# 1638   C829  C82.9 Follicular non-Hodgkin's lymphoma; unspe...          19
# 1631   C821  C82.1 Mixed small cleaved and large cell; foll...          19
# 1630   C820               C82.0 Small cleaved cell; follicular          19
# 1632   C822                       C82.2 Large cell; follicular          19
# 1637   C827  C82.7 Other types of follicular non-Hodgkin's ...          19
# 1629    C82    C82 Follicular [nodular] non-Hodgkin's lymphoma          19
# 1633   C823               C82.3 Follicular lymphoma grade IIIa          19
# 1634   C824               C82.4 Follicular lymphoma grade IIIb          19
# 1635   C825             C82.5 Diffuse follicle centre lymphoma          19
# 1636   C826           C82.6 Cutaneous follicle centre lymphoma          19
#
#                    name  count
# 1638  cancer_type_ICD10    301
# 1631  cancer_type_ICD10     77
# 1630  cancer_type_ICD10     41
# 1632  cancer_type_ICD10     40
# 1637  cancer_type_ICD10     23
# 1629  cancer_type_ICD10      0
# 1633  cancer_type_ICD10      0
# 1634  cancer_type_ICD10      0
# 1635  cancer_type_ICD10      0
# 1636  cancer_type_ICD10      0
#      coding                                            meaning code_format  \
# 1638   C829  C82.9 Follicular non-Hodgkin's lymphoma; unspe...          19
# 1666   C859     C85.9 Non-Hodgkin's lymphoma; unspecified type          19
# 1648   C838  C83.8 Other types of diffuse non-Hodgkin's lym...          19
# 1665   C857  C85.7 Other specified types of non-Hodgkin's l...          19
# 1637   C827  C82.7 Other types of follicular non-Hodgkin's ...          19
# 1649   C839  C83.9 Diffuse non-Hodgkin's lymphoma; unspecified          19
#
#                    name  count
# 1638  cancer_type_ICD10    301
# 1666  cancer_type_ICD10    237
# 1648  cancer_type_ICD10    117
# 1665  cancer_type_ICD10    115
# 1637  cancer_type_ICD10     23
# 1649  cancer_type_ICD10     14

# %%
# https://www.ncbi.nlm.nih.gov/pmc/articles/PMC7125417/
viral_associated_cancers = ["hodgkin's lymphoma", "gastric carcinoma", "burkitt's lymphoma", "nasopharyngeal carcinoma"]
ICD10_viral_associated_cancer_labels = {
    "burkitt's lymphoma": ["C83.7"],
    "nasopharyngeal carcinoma": ["C11"],
    "gastric carcinoma": ["C16", "D37.1"],
    "hodgkin's disease": ["C81.9", "C81.7"],
    "kaposi's sarcoma": ["C46"],
    "liver cancer": ["C22"],
#     "anal cancer": ["C21"],
#     "non-hodgkin's lymphoma": ["C82.9", "C82.7", "C83.8", "C85.7", "C83.9"]
}

viral_labels = {
    "mononucleosis_code": 'infectious mononucleosis / glandular fever / epstein barr virus (ebv)',
    "hiv_code": 'hiv/aids',
    "herpes_simplex_code": "herpes simplex",
    "hepatitis_code": "infective/viral hepatitis"
}

antiviral_labels = {"acyclovir": "clovir"}

ICD10_viral_associated_cancer_labels
# Out:
# {"burkitt's lymphoma": ['C83.7'],
#  'nasopharyngeal carcinoma': ['C11'],
#  'gastric carcinoma': ['C16', 'D37.1'],
#  "hodgkin's disease": ['C81.9', 'C81.7'],
#  "kaposi's sarcoma": ['C46'],
#  'liver cancer': ['C22']}

# %%
def apply_grouping(variable_tag: str, grouping: dict, default: str = None) -> str:
    """"""
    if isinstance(variable_tag, float):
        return default
    
    for label, tag_set in grouping.items():
        if isinstance(tag_set, str):
            if tag_set in variable_tag:
                return label
            continue

        for tag in tag_set:
            if tag in variable_tag:
                return label

    return default

def apply_tuple_grouping(variable_tag: str, grouping: tuple, default: str = None) -> str:
    """"""
    if isinstance(variable_tag, float):
        return default
    
    for label, tag_set in grouping:
        if isinstance(tag_set, str):
            if tag_set in variable_tag:
                return label
            continue

        for tag in tag_set:
            if tag in variable_tag:
                return label

    return default

# def multicolumn_apply_grouping()

# %%
base_feature = "illness_code"
params = dict(grouping=[(True, "infective/viral hepatitis"), (True, "hepatitis a")], default=False)

features = [feature for feature in ICD10_data.columns if feature.startswith(base_feature + "_0")]
aggregated_feature_values = ICD10_data[features[0]].apply(apply_tuple_grouping, **params)

for feature in features[1:]:
    found_values = ICD10_data[feature].apply(apply_tuple_grouping, **params)
    aggregated_feature_values = aggregated_feature_values | found_values
    
ICD10_data["infective/viral hepatitis"] = aggregated_feature_values * 1

# %%
ICD10_data["viral_infection"] = ICD10_data["illness_code"].apply(apply_grouping, grouping=viral_labels,
                                                                 default="no viral illness")
ICD10_data["given_antiviral"] = ICD10_data["treatment_code"].apply(apply_grouping, grouping=antiviral_labels,
                                                                 default="no antiviral")

# %%
ICD10_data["virus_associated_cancer"] = ICD10_data["cancer_type_ICD10"].apply(apply_grouping, 
                                                                              grouping=ICD10_viral_associated_cancer_labels,
                                                                              default="non-virus associated")

biobank_data["virus_associated_cancer"] = biobank_data["cancer_type_ICD10"].apply(apply_grouping, 
                                                                              grouping=ICD10_viral_associated_cancer_labels,
                                                                              default="non-virus associated")

# %%
biobank_data["virus_associated_cancer"].loc[biobank_data["cancer_type_ICD10"].isna()] = "no cancer"
# Out:
# <ipython-input-503-9a5cdfa039cb>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   biobank_data["virus_associated_cancer"].loc[biobank_data["cancer_type_ICD10"].isna()] = "no cancer"

# %% [markdown]
# # Viral Associated Summary Statistics

# %%
variables_of_interest = ["sex"]
grouping = ["virus_associated_cancer"]
extra = ["zygosity"]

grouping_df = biobank_data[grouping + variables_of_interest + extra].copy(deep=True)
grouping_df["total"] = grouping_df[variables_of_interest[0]] != "nothing"

for variable in variables_of_interest:
    for variable_option in sorted(grouping_df[variable].unique()):
        grouping_df[variable_option.lower().replace(" ", "_")] = grouping_df[variable] == variable_option

grouping_df = grouping_df.groupby(grouping).sum().reset_index()

# for variable in exclude(grouping_df.columns, grouping + ["total"]):
#     grouping_df[variable + "_fraction"] = grouping_df[variable] / grouping_df["total"]

grouping_df = grouping_df.sort_values("total", ascending=False)
grouping_df["zygosity"] /= grouping_df["total"]
grouping_df = grouping_df.rename({"zygosity": "mean_hla_homozygosity"}, axis=1)
display(grouping_df)
# Out:
#     virus_associated_cancer  mean_hla_homozygosity   total  female    male
# 6                 no cancer               0.314676  419053  227161  191892
# 7      non-virus associated               0.324993   82488   45897   36591
# 1         gastric carcinoma               0.316929     508     166     342
# 4              liver cancer               0.292308     325     118     207
# 2         hodgkin's disease               0.400000      90      42      48
# 5  nasopharyngeal carcinoma               0.187500      32      14      18
# 0        burkitt's lymphoma               0.400000      25       4      21
# 3          kaposi's sarcoma               0.066667      15       0      15

# %%
data = grouping_df.copy(deep=True)
data["mean_hla_homozygosity"] = data["mean_hla_homozygosity"].apply(lambda s: f"{s:.3f}")
fig, ax = render_mpl_table(data, header_columns=0, col_width=4.0)
fig.savefig("cancer_ICD10_plots/viral_associated_cancer_summary_table.png")
grouping_df = grouping_df.loc[~ grouping_df["virus_associated_cancer"].isin(["no cancer", "non-virus associated"])]

# %%
data = grouping_df
fig, ax = plt.subplots(figsize=(12, 6))
sns.barplot(data=data, x="virus_associated_cancer", y="total", color="C0", alpha=.8, label="Female")
sns.barplot(data=data, x="virus_associated_cancer", y="male", color="orange", alpha=1, label="Male")

i = 0
for y_i, frac_male in zip(data["male"], data["male"] / data["total"]):
    ax.text(i, max(y_i * .8, 15), f"{frac_male * 100:.02f}%", ha="center", va="top")
    i += 1

add_plt_labels(ax=ax, x="Cancer Type", y="Count")
ax.legend(title="Sex")
ax.set_title("UK BioBank Viral Associated Cancers")
ax.set_xticklabels([t._text.title() for t in ax.get_xticklabels()], rotation="-60", ha="left");
fig.savefig("cancer_ICD10_plots/viral_associated_cancer_summary.png")

# %% [markdown]
# # Viral Associated Age of Diagnosis Plots

# %%
grouping = ICD10_data.groupby(["virus_associated_cancer"])
grouping = {label: subset for label, subset in grouping}

x, y, hue = "cancer_dx_age_interpolated", "density", "sex"

fig, axes = create_subplot(len(grouping), width=20, height_per=3)
for (cancer_type, subset), ax in zip(ICD10_data.groupby(["virus_associated_cancer"]), axes):
    sns_wrapper(sns.kdeplot, data=subset, x=x, hue=hue, ax=ax, bw_method=.35, common_norm=False, shade=True)
#     sns.histplot(data=subset, x=x, hue=hue, ax=ax, multiple="dodge", alpha=.3)
    add_plt_labels(ax, x=x, y=y)
    ax.set_title(f"{cancer_type.title()} Diagnosis Age")
    ax.legend(loc="upper left")

fig.tight_layout()
fig.savefig("cancer_ICD10_plots/viral_associated_cancer_age_dx.png")

# %%
fig, ax = plt.subplots(figsize=(20, 6))
sns.boxplot(data=biobank_data.query("sex == 'Male'"), x="virus_associated_cancer", hue="zygosity", y=x, ax=ax)
# add_plt_labels(ax, x="Number of Homozygous HLA Alleles", y=x)
# Out:
# <AxesSubplot:xlabel='virus_associated_cancer', ylabel='cancer_dx_age_interpolated'>

# %%
cancer_types = sorted(biobank_data["virus_associated_cancer"].unique())
cancer_types = [c for c in cancer_types if c != "no cancer"] + ["no cancer"]

values = []
for zygosity in range(3):
    data = biobank_data.query(f"zygosity == {zygosity}")
    values.append([(data["virus_associated_cancer"] == cancer_type).sum() for cancer_type in cancer_types])
values = np.cumsum(values, axis=0)
counts = values[-1]
values = values / counts

fig, ax = plt.subplots(figsize=(14, 6))
for i, value_set in zip(range(3), values):
    ax.bar(cancer_types, value_set, label=i, zorder=- i)

ax.legend(title="HLA Zygosity")
plt.draw()
ax.set_xticklabels([t._text.title() for t in ax.get_xticklabels()], rotation="-60", ha="left");
ax.set_xlim(-.2, len(counts) + .4)
# Out:
# <ipython-input-509-9cd323754397>:18: UserWarning: FixedFormatter should only be used together with FixedLocator
#   ax.set_xticklabels([t._text.title() for t in ax.get_xticklabels()], rotation="-60", ha="left");
# (-0.2, 8.4)

# %%
grouping = ICD10_data.query("sex == 'Male'").groupby(["virus_associated_cancer"])
grouping = {label: subset for label, subset in grouping}

x, y, hue = "cancer_dx_age_interpolated", "density", "zygosity"

fig, axes = create_subplot(len(grouping), width=20, height_per=3)
for (cancer_type, subset), ax in zip(ICD10_data.groupby(["virus_associated_cancer"]), axes):
    sns_wrapper(sns.kdeplot, data=subset, x=x, hue=hue, ax=ax, bw_method=.35, common_norm=False, shade=True)
#     sns.histplot(data=subset, x=x, hue=hue, ax=ax, multiple="dodge", alpha=.3)
    add_plt_labels(ax, x=x, y=y)
    ax.set_title(f"{str(cancer_type).title()} Diagnosis Age")
    ax.legend(loc="upper left")

fig.tight_layout()
fig.savefig("cancer_ICD10_plots/viral_associated_cancer_age_dx.png")
# Out:
# /Users/cole/miniconda3/lib/python3.9/site-packages/seaborn/distributions.py:316: UserWarning: Dataset has 0 variance; skipping density estimate. Pass `warn_singular=False` to disable this warning.
#   warnings.warn(msg, UserWarning)
# /Users/cole/miniconda3/lib/python3.9/site-packages/seaborn/distributions.py:316: UserWarning: Dataset has 0 variance; skipping density estimate. Pass `warn_singular=False` to disable this warning.
#   warnings.warn(msg, UserWarning)

# %% [markdown]
# # Autoimmune

# %%
import scipy.stats as stats

# %%
def zygosity_OR_test(data) -> str:
    """ """
    text = ""
    
    for value in range(1, 4):
        disease, no_disease = data["illness_value"], ~data["illness_value"]
        exposure, no_exposure = data["zygosity"] == value, data["zygosity"] == 0

        disease_exposure = np.sum(disease & exposure)
        disease_no_exposure = np.sum(disease & no_exposure)
        no_disease_exposure = np.sum(no_disease & exposure)
        no_disease_no_exposure = np.sum(no_disease & no_exposure)
        N = disease_exposure

        table = [[disease_exposure, no_disease_exposure], [disease_no_exposure, no_disease_no_exposure]]

        odds_ratio, p_value = stats.fisher_exact(table)

        standard_error = np.sqrt(np.sum(1 / np.array([disease_exposure, disease_no_exposure,
                                                    no_disease_exposure, no_disease_no_exposure])))
        z_score = 1.96

        upper_bound = np.exp(np.log(odds_ratio) + z_score * standard_error)
        lower_bound = np.exp(np.log(odds_ratio) - z_score * standard_error)
        p_value_str = f"{p_value:.2}" if "e" in str(p_value) else f"{p_value:.5f}"
        line = f"Zygosity = {value}   OR: {odds_ratio:.3f}   P-Value: {p_value_str}" 
        line += f"   95% CI: {lower_bound:.2f} - {upper_bound:.2f}   N = {N:,}"
        text += line + "\n"

    return text

# %%
for illness in psychiatric_conditions:
    print(illness.upper())
    data["illness_value"] = 1 * (biobank_data["illness_code"] == illness)
    print("\t" + zygosity_OR_test(data).replace('\n', '\n\t'))
# Out:
# SCHIZOPHRENIA
# 	Zygosity = 1   OR: nan   P-Value: 1.00000   95% CI: nan - nan   N = 0
# 	Zygosity = 2   OR: nan   P-Value: 1.00000   95% CI: nan - nan   N = 10
# 	Zygosity = 3   OR: nan   P-Value: 1.00000   95% CI: nan - nan   N = 0
#
# DEPRESSION
# 	Zygosity = 1   OR: nan   P-Value: 1.00000   95% CI: nan - nan   N = 0
# 	Zygosity = 2   OR: nan   P-Value: 1.00000   95% CI: nan - nan   N = 340
# 	Zygosity = 3   OR: nan   P-Value: 1.00000   95% CI: nan - nan   N = 0
#
# MANIA/BIPOLAR DISORDER/MANIC DEPRESSION
# 	Zygosity = 1   OR: nan   P-Value: 1.00000   95% CI: nan - nan   N = 0
# 	Zygosity = 2   OR: nan   P-Value: 1.00000   95% CI: nan - nan   N = 20
# 	Zygosity = 3   OR: nan   P-Value: 1.00000   95% CI: nan - nan   N = 0
#
# OBSESSIVE COMPULSIVE DISORDER (OCD)
# 	Zygosity = 1   OR: nan   P-Value: 1.00000   95% CI: nan - nan   N = 0
# 	Zygosity = 2   OR: nan   P-Value: 1.00000   95% CI: nan - nan   N = 1
# 	Zygosity = 3   OR: nan   P-Value: 1.00000   95% CI: nan - nan   N = 0
#
# ANXIETY/PANIC ATTACKS
# 	Zygosity = 1   OR: nan   P-Value: 1.00000   95% CI: nan - nan   N = 0
# 	Zygosity = 2   OR: nan   P-Value: 1.00000   95% CI: nan - nan   N = 98
# 	Zygosity = 3   OR: nan   P-Value: 1.00000   95% CI: nan - nan   N = 0
#
# ALCOHOL DEPENDENCY
# 	Zygosity = 1   OR: nan   P-Value: 1.00000   95% CI: nan - nan   N = 0
# 	Zygosity = 2   OR: nan   P-Value: 1.00000   95% CI: nan - nan   N = 14
# 	Zygosity = 3   OR: nan   P-Value: 1.00000   95% CI: nan - nan   N = 0
# <ipython-input-513-f7194c5efa46>:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data["illness_value"] = 1 * (biobank_data["illness_code"] == illness)
# <ipython-input-512-8d95a531e049>:19: RuntimeWarning: divide by zero encountered in true_divide
#   standard_error = np.sqrt(np.sum(1 / np.array([disease_exposure, disease_no_exposure,

# %%
condition = "autoimmune"

conditions = HLA_dosing_conditions[condition]

big_fig, big_axes = create_subplot(len(conditions), width=20, height_per=3, wspace=.1)

for illness, big_ax in tqdm(zip(conditions, big_axes), unit=" plot", desc="Making OR Plots",
                            total=len(big_axes)):

    fig, ax = plt.subplots(figsize=(14, 6))
    x = "grantham_divergence"
    data["illness_value"] = 1 * (biobank_data["illness_code"] == illness)
    data["illness"] = np.array(["no " + illness, illness])[data["illness_value"].values]
    sns_wrapper(sns.kdeplot, data=data, x=x, hue="illness", ax=ax, bw_method=.1, common_norm=False, shade=True)
    sns_wrapper(sns.kdeplot, data=data, x=x, hue="illness", ax=big_ax, bw_method=.1, common_norm=False, shade=True)
    
    text = zygosity_OR_test(data)

    add_plt_labels(ax, x=x)
    ax.set_title(f"{illness.title()} HLA Class I Grantham Distance")
    ax.text(0.025, 0.95, text, transform=ax.transAxes, ha="left", va="top")
    
    add_plt_labels(big_ax, x=x)
    big_ax.set_title(f"{illness.title()} HLA Class I Grantham Distance")
    big_ax.text(0.025, 0.95, text, transform=big_ax.transAxes, ha="left", va="top", fontsize=12)
    big_ax.legend(title="Illness", loc="center left")
    big_ax.set_xlim(10, 40)
    
    illness_label = illness.replace(' ', '_').replace('/', '_').replace("'", "")
    fig.savefig(f"cancer_ICD10_plots/grantham_distance_plots/{condition}/HLA_grantham_distance_{illness_label}.png")

big_fig.savefig(f"cancer_ICD10_plots/grantham_distance_plots/{condition}/multiple_HLA_grantham_distance.png")
# Out:
# Making OR Plots:   0%|          | 0/17 [00:00<?, ? plot/s]
