# %%
# %load_ext autoreload
# %autoreload 2

import os
import sys
HLA_associations_path = os.path.abspath("../")
sys.path.append(HLA_associations_path)

import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from tqdm.notebook import tqdm

import constants, index_tools, data_tools, medical_code_tools
from utilities import *

# %%
sns.set_palette("tab10")
plt.rcParams.update({'figure.max_open_warning': 0})

# %%
loaded = False

# %% [markdown]
# # Load BioBank Components

# %%
DEV_MODE = False
SIGNIFIER = ""

if not loaded:
    biobank_data, biobank_index, med_code_mapping = data_tools.load_all_biobank_components(DEV_MODE, signifier=SIGNIFIER)
    loaded = True
# Out:
# Importing BioBank Index and Data:
# Missing 0 biobank index names
# Reduced feature set has 369 features.
# UK BioBank Data Loaded.
# Size: 502536 rows x 369 columns
# Elapsed time: 62.4698 seconds
# Mapping Medical Codes:   0%|          | 0/354 [00:00<?, ? feature/s]

# %% [markdown]
# # Constants

# %%
female_specific_cancers = ["breast cancer", "female genital tract cancer", "cervical cancer",
                           "cin/pre-cancer cells cervix", "fallopian tube cancer", "ovarian cancer",
                           "uterine/endometrial cancer", "vaginal cancer", "vulval cancer" ]

male_specific_cancers = ["male genital tract cancer", "penis cancer", "prostate cancer", "testicular cancer"]
sex_specific_cancers = female_specific_cancers + male_specific_cancers

# %% [markdown]
# # Viral Codes

# %%
ICD10_data["illness"]

# %%
mononucleosis_code = 'infectious mononucleosis / glandular fever / epstein barr virus (ebv)'
hiv_code = 'hiv/aids'
herpes_simplex_code = "herpes simplex"
hepatitis_code = "infective/viral hepatitis"

data_tools.biobank_search(med_code_mapping, biobank_data, ("viral"))
# Out:
#       coding                                            meaning code_format  \
# 74      1156                          infective/viral hepatitis           6
# 552      049  049 Other non-arthropod-borne viral diseases o...          87
# 555     0498  0498 Other non-arthropod-borne viral diseases ...          87
# 556     0499  0499 Unspecified non-arthropod-borne viral dis...          87
# 599      057                        057 Other viral exanthemata          87
# ...      ...                                                ...         ...
# 18576    Z24  Z24 Need for immunisation against certain sing...          19
# 18578   Z241  Z24.1 Need for immunisation against arthropod-...          19
# 18583   Z246  Z24.6 Need for immunisation against viral hepa...          19
# 18584    Z25  Z25 Need for immunisation against other single...          19
# 18587   Z258  Z25.8 Need for immunisation against other spec...          19
#
#                     name  count
# 74          illness_code    474
# 552     cancer_type_ICD9      0
# 555     cancer_type_ICD9      0
# 556     cancer_type_ICD9      0
# 599     cancer_type_ICD9      0
# ...                  ...    ...
# 18576  cancer_type_ICD10      0
# 18578  cancer_type_ICD10      0
# 18583  cancer_type_ICD10      0
# 18584  cancer_type_ICD10      0
# 18587  cancer_type_ICD10      0
#
# [208 rows x 5 columns]

# %% [markdown]
#  # Exploring ICD 10 Cancer Types

# %%
ICD10_data = biobank_data.loc[~biobank_data["cancer_type_ICD10"].isna()].copy(deep=True)

# %%
display(data_tools.biobank_search(med_code_mapping, biobank_data, ("C46")).query("name == 'cancer_type_ICD10'"))
display(data_tools.biobank_search(med_code_mapping, biobank_data,
                                  ("kaposi")).query("name == 'cancer_type_ICD10' and count != 0"))
# Out:
#      coding                                    meaning code_format  \
# 1421   C460             C46.0 Kaposi's sarcoma of skin          19
# 1425   C467      C46.7 Kaposi's sarcoma of other sites          19
# 1422   C461      C46.1 Kaposi's sarcoma of soft tissue          19
# 1427   C469        C46.9 Kaposi's sarcoma; unspecified          19
# 1420    C46                       C46 Kaposi's sarcoma          19
# 1423   C462           C46.2 Kaposi's sarcoma of palate          19
# 1424   C463      C46.3 Kaposi's sarcoma of lymph nodes          19
# 1426   C468  C46.8 Kaposi's sarcoma of multiple organs          19
#
#                    name  count
# 1421  cancer_type_ICD10     11
# 1425  cancer_type_ICD10      2
# 1422  cancer_type_ICD10      1
# 1427  cancer_type_ICD10      1
# 1420  cancer_type_ICD10      0
# 1423  cancer_type_ICD10      0
# 1424  cancer_type_ICD10      0
# 1426  cancer_type_ICD10      0
#      coding                                meaning code_format  \
# 1421   C460         C46.0 Kaposi's sarcoma of skin          19
# 1425   C467  C46.7 Kaposi's sarcoma of other sites          19
# 1422   C461  C46.1 Kaposi's sarcoma of soft tissue          19
# 1427   C469    C46.9 Kaposi's sarcoma; unspecified          19
#
#                    name  count
# 1421  cancer_type_ICD10     11
# 1425  cancer_type_ICD10      2
# 1422  cancer_type_ICD10      1
# 1427  cancer_type_ICD10      1

# %%
# https://www.ncbi.nlm.nih.gov/pmc/articles/PMC7125417/
viral_associated_cancers = ["hodgkin's lymphoma", "gastric carcinoma", "burkitt's lymphoma", "nasopharyngeal carcinoma"]
ICD10_viral_associated_cancer_labels = {
    "burkitt's lymphoma": ["C83.7"],
    "nasopharyngeal carcinoma": ["C11"],
    "gastric carcinoma": ["C16", "D37.1"],
    "hodgkin's disease": ["C81.9", "C81.7"],
    "kaposi's sarcoma": ["C46"]
}

viral_labels = {
    "mononucleosis_code": 'infectious mononucleosis / glandular fever / epstein barr virus (ebv)',
    "hiv_code": 'hiv/aids',
    "herpes_simplex_code": "herpes simplex",
    "hepatitis_code": "infective/viral hepatitis"
}

ICD10_viral_associated_cancer_labels
# Out:
# {"burkitt's lymphoma": ['C83.7'],
#  'nasopharyngeal carcinoma': ['C11'],
#  'gastric carcinoma': ['C16', 'D37.1'],
#  "hodgkin's disease": ['C81.9', 'C81.7'],
#  "kaposi's sarcoma": ['C46']}

# %%
def apply_grouping(variable_tag: str, grouping: dict, default: str = None) -> str:
    """"""
    for label, tag_set in grouping.items():
        if isinstance(tag_set, str):
            if tag_set in label:
                return label
            else:
                return default

        for tag in tag_set:
            if tag in variable_tag:
                return label
    return default

# %%
ICD10_data["illness_code"].apply(apply_grouping, grouping=viral_labels, default="no viral illness")
# Out:
# mononucleosis_code infectious mononucleosis / glandular fever / epstein barr virus (ebv)
# here
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Input In [51], in <cell line: 1>()
# ----> 1 ICD10_data["illness_code"].apply(apply_grouping, grouping=viral_labels, default="no viral illness")
#
# File ~/miniconda3/lib/python3.9/site-packages/pandas/core/series.py:4433, in Series.apply(self, func, convert_dtype, args, **kwargs)
#    4323 def apply(
#    4324     self,
#    4325     func: AggFuncType,
#    (...)
#    4328     **kwargs,
#    4329 ) -> DataFrame | Series:
#    4330     """
#    4331     Invoke function on values of Series.
#    4332
#    (...)
#    4431     dtype: float64
#    4432     """
# -> 4433     return SeriesApply(self, func, convert_dtype, args, kwargs).apply()
#
# File ~/miniconda3/lib/python3.9/site-packages/pandas/core/apply.py:1082, in SeriesApply.apply(self)
#    1078 if isinstance(self.f, str):
#    1079     # if we are a string, try to dispatch
#    1080     return self.apply_str()
# -> 1082 return self.apply_standard()
#
# File ~/miniconda3/lib/python3.9/site-packages/pandas/core/apply.py:1137, in SeriesApply.apply_standard(self)
#    1131         values = obj.astype(object)._values
#    1132         # error: Argument 2 to "map_infer" has incompatible type
#    1133         # "Union[Callable[..., Any], str, List[Union[Callable[..., Any], str]],
#    1134         # Dict[Hashable, Union[Union[Callable[..., Any], str],
#    1135         # List[Union[Callable[..., Any], str]]]]]"; expected
#    1136         # "Callable[[Any], Any]"
# -> 1137         mapped = lib.map_infer(
#    1138             values,
#    1139             f,  # type: ignore[arg-type]
#    1140             convert=self.convert_dtype,
#    1141         )
#    1143 if len(mapped) and isinstance(mapped[0], ABCSeries):
#    1144     # GH#43986 Need to do list(mapped) in order to get treated as nested
#    1145     #  See also GH#25959 regarding EA support
#    1146     return obj._constructor_expanddim(list(mapped), index=obj.index)
#
# File ~/miniconda3/lib/python3.9/site-packages/pandas/_libs/lib.pyx:2870, in pandas._libs.lib.map_infer()
#
# File ~/miniconda3/lib/python3.9/site-packages/pandas/core/apply.py:138, in Apply.__init__.<locals>.f(x)
#     137 def f(x):
# --> 138     return func(x, *args, **kwargs)
#
# Input In [50], in apply_grouping(variable_tag, grouping, default)
#       8             return label
#      10     for tag in tag_set:
# ---> 11         if tag in variable_tag:
#      12             return label
#      13 return default
#
# TypeError: argument of type 'float' is not iterable

# %%
ICD10_data["virus_associated_status"] = ICD10_data["cancer_type_ICD10"].apply(apply_grouping, 
                                                                              grouping=ICD10_viral_associated_cancer_labels,
                                                                              default="non-viral associated")

# %% [markdown]
# # Viral Associated Summary Statistics

# %%
variables_of_interest = ["sex", "virus_associated_status", "illness_code"]

grouping_df = ICD10_data[variables_of_interest].copy(deep=True)
grouping_df["total"] = grouping_df["sex"] != "nothing"
grouping_df["female"] = grouping_df["sex"] == "Female"
grouping_df["male"] = grouping_df["sex"] == "Male"
grouping_df = grouping_df.groupby("virus_associated_status").sum().reset_index()

grouping_df = grouping_df.loc[ ~grouping_df["virus_associated_status"].isin(sex_specific_cancers)]
most_common_cancers = grouping_df["virus_associated_status"]

grouping_df["male_fraction"] = grouping_df["male"] / grouping_df["total"]
grouping_df["female_fraction"] = grouping_df["female"] / grouping_df["total"]
grouping_df
# Out:
#     virus_associated_status  total  female   male  male_fraction  \
# 0        burkitt's lymphoma     25       4     21       0.840000
# 1         gastric carcinoma    508     166    342       0.673228
# 2         hodgkin's disease     90      42     48       0.533333
# 3          kaposi's sarcoma     15       0     15       1.000000
# 4  nasopharyngeal carcinoma     32      14     18       0.562500
# 5      non-viral associated  82813   46015  36798       0.444351
#
#    female_fraction
# 0         0.160000
# 1         0.326772
# 2         0.466667
# 3         0.000000
# 4         0.437500
# 5         0.555649

# %% [markdown]
# # Viral Associated Age of Diagnosis Plots

# %%
grouping = ICD10_data.groupby(["virus_associated_status"])
grouping = {label: subset for label, subset in grouping}

x, y, hue = "cancer_dx_age_interpolated", "density", "sex"

fig, axes = create_subplot(len(grouping), width=12, height_per=3)
for (cancer_type, subset), ax in zip(ICD10_data.groupby(["virus_associated_status"]), axes):
    sns_wrapper(sns.kdeplot, data=subset, x=x, hue=hue, ax=ax, bw_method=.4, common_norm=False, shade=True)
#     sns.histplot(data=subset, x=x, hue=hue, ax=ax, multiple="dodge", alpha=.3)
    add_plt_labels(ax, x=x, y=y)
    ax.set_title(f"{cancer_type.title()} Diagnosis Age")

fig.tight_layout()
